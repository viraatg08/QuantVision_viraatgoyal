# %% [markdown]
# <a href="https://colab.research.google.com/github/kushallkharkia-cmyk/QuantVision/blob/main/A1_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install yfinance

# %%
pip install plotly

# %% [markdown]
# ![newplot (1).png](data:image/png;base64,...)

# %%
import yfinance as yf
ticker = 'GS'
stock = yf.Ticker(ticker)
df = stock.history(period='6mo', interval='1d')

# %%
import plotly.graph_objects as go
fig = go.Figure(data=[go.Candlestick(
    x=df.index,
    open=df['Open'],
    high=df['High'],
    low=df['Low'],
    close=df['Close'],
    name=ticker
)])
fig.update_layout(
    title=f'Goldman Sachs ({ticker}) - 6 Month History',
    yaxis_title='Stock Price (USD)',
    xaxis_title='Date',
    xaxis_rangeslider_visible=False,
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 1. 25-26 August,2025
# 2. Bullish Engulf
# 3. The closing price of next day(27th August, 2025) increased than the closing of 26th.
